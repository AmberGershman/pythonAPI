# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_py = pd.read_csv("WeatherPy_Results.csv")
weather_py
# Out:
#                   City  Latitude  Longitude  Max Temperature  Humidity  \
# 0                 Hilo     19.73    -155.09            28.00        65
# 1        Alice Springs    -23.70     133.88            16.00        29
# 2               Hobart    -42.88     147.33             4.00        80
# 3                 Chui    -33.70     -53.46            16.51        85
# 4               Sittwe     20.15      92.90            27.69        87
# ..                 ...       ...        ...              ...       ...
# 562             Dwārka     22.24      68.97            28.59        83
# 563              Tynda     55.17     124.72            11.59        93
# 564              Horia     45.02      28.45            23.00        49
# 565           Tshikapa     -6.42      20.80            25.05        53
# 566  Sosnovo-Ozerskoye     52.52     111.54            12.31        95
#
#      Cloudiness  Wind Speed Country        Date
# 0            20        3.10      US  1597091250
# 1            11        5.70      AU  1597091448
# 2            20        3.60      AU  1597090972
# 3            80        2.30      UY  1597091212
# 4           100        3.77      MM  1597091213
# ..          ...         ...     ...         ...
# 562         100        7.76      IN  1597092118
# 563          83        2.22      RU  1597092119
# 564          16        1.50      RO  1597092121
# 565           1        1.10      CD  1597092122
# 566         100        1.24      RU  1597092123
#
# [567 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)
locations = weather_py[["Latitude", "Longitude"]]
humid = weather_py["Humidity"]

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humid, 
                                 dissipating=False, max_intensity=10,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_conditions = weather_py.loc[weather_py["Max Temperature"] < 90, :]
ideal_conditions = weather_py.loc[weather_py["Max Temperature"] > 45, :]
ideal_conditions = weather_py.loc[weather_py["Humidity"] < 60, :]
ideal_conditions.dropna(axis = 1)
ideal_conditions
# Out:
#                     City  Latitude  Longitude  Max Temperature  Humidity  \
# 1          Alice Springs    -23.70     133.88            16.00        29
# 9         Guerrero Negro     27.98    -114.06            29.76        41
# 10                 Aswān     24.09      32.91            37.00        17
# 13                Lumeje    -11.55      20.78            18.55        28
# 23                 Craig     40.52    -107.55            33.00         9
# ..                   ...       ...        ...              ...       ...
# 557  Saint-Jean-de-Braye     47.91       1.98            30.00        40
# 558        Mountain Home     43.13    -115.69            30.00        15
# 559         Saint-Joseph    -21.37      55.62            20.00        49
# 564                Horia     45.02      28.45            23.00        49
# 565             Tshikapa     -6.42      20.80            25.05        53
#
#      Cloudiness  Wind Speed Country        Date
# 1            11        5.70      AU  1597091448
# 9             0        4.50      MX  1597091219
# 10            0        4.10      EG  1597091220
# 13            0        1.95      AO  1597091223
# 23            1        3.60      US  1597091235
# ..          ...         ...     ...         ...
# 557          19        3.10      FR  1597092113
# 558           1        2.60      US  1597092114
# 559          90        3.60      RE  1597092115
# 564          16        1.50      RO  1597092121
# 565           1        1.10      CD  1597092122
#
# [125 rows x 9 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = ideal_conditions
hotel_df["Hotel Name"] = ""
hotel_df["Hotel Rating"] = ""
hotel_df["Hotel Address"] = ""
hotel_df
# Out:
# C:\Users\Amber\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Amber\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Amber\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                     City  Latitude  Longitude  Max Temperature  Humidity  \
# 1          Alice Springs    -23.70     133.88            16.00        29
# 9         Guerrero Negro     27.98    -114.06            29.76        41
# 10                 Aswān     24.09      32.91            37.00        17
# 13                Lumeje    -11.55      20.78            18.55        28
# 23                 Craig     40.52    -107.55            33.00         9
# ..                   ...       ...        ...              ...       ...
# 557  Saint-Jean-de-Braye     47.91       1.98            30.00        40
# 558        Mountain Home     43.13    -115.69            30.00        15
# 559         Saint-Joseph    -21.37      55.62            20.00        49
# 564                Horia     45.02      28.45            23.00        49
# 565             Tshikapa     -6.42      20.80            25.05        53
#
#      Cloudiness  Wind Speed Country        Date Hotel Name Hotel Rating  \
# 1            11        5.70      AU  1597091448
# 9             0        4.50      MX  1597091219
# 10            0        4.10      EG  1597091220
# 13            0        1.95      AO  1597091223
# 23            1        3.60      US  1597091235
# ..          ...         ...     ...         ...        ...          ...
# 557          19        3.10      FR  1597092113
# 558           1        2.60      US  1597092114
# 559          90        3.60      RE  1597092115
# 564          16        1.50      RO  1597092121
# 565           1        1.10      CD  1597092122
#
#     Hotel Address
# 1
# 9
# 10
# 13
# 23
# ..            ...
# 557
# 558
# 559
# 564
# 565
#
# [125 rows x 12 columns]

# %%
hotel_name = []
hotel_rating = []
vicinity = []
params = {
    "radius": 50000,
    "types": "hotel",
    "keyword": "hotel",
    "key": g_key
}

for index, row in hotel_df.iterrows():
    lat = row["Latitude"]
    lng = row["Longitude"]
    
    params["location"] = f"{lat},{lng}"
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    name_address = requests.get(base_url, params=params)
    name_address = name_address.json()

    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["results"][0]["name"]
        hotel_df.loc[index, "Hotel Address"] = name_address["results"][0]["vicinity"]
        hotel_df.loc[index, "Hotel Rating"] = name_address["results"][0]["rating"]
    except (KeyError, IndexError):
        print("Nope - can't find data for this one. You DON'T GET TO VACATION HERE")
# Out:
# C:\Users\Amber\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Nope - can't find data for this one. You DON'T GET TO VACATION HERE
# Nope - can't find data for this one. You DON'T GET TO VACATION HERE
# Nope - can't find data for this one. You DON'T GET TO VACATION HERE
# Nope - can't find data for this one. You DON'T GET TO VACATION HERE
# Nope - can't find data for this one. You DON'T GET TO VACATION HERE
# Nope - can't find data for this one. You DON'T GET TO VACATION HERE
# Nope - can't find data for this one. You DON'T GET TO VACATION HERE
# Nope - can't find data for this one. You DON'T GET TO VACATION HERE
# Nope - can't find data for this one. You DON'T GET TO VACATION HERE

# %%
hotel_df
# Out:
#                     City  Latitude  Longitude  Max Temperature  Humidity  \
# 1          Alice Springs    -23.70     133.88            16.00        29
# 9         Guerrero Negro     27.98    -114.06            29.76        41
# 10                 Aswān     24.09      32.91            37.00        17
# 13                Lumeje    -11.55      20.78            18.55        28
# 23                 Craig     40.52    -107.55            33.00         9
# ..                   ...       ...        ...              ...       ...
# 557  Saint-Jean-de-Braye     47.91       1.98            30.00        40
# 558        Mountain Home     43.13    -115.69            30.00        15
# 559         Saint-Joseph    -21.37      55.62            20.00        49
# 564                Horia     45.02      28.45            23.00        49
# 565             Tshikapa     -6.42      20.80            25.05        53
#
#      Cloudiness  Wind Speed Country        Date  \
# 1            11        5.70      AU  1597091448
# 9             0        4.50      MX  1597091219
# 10            0        4.10      EG  1597091220
# 13            0        1.95      AO  1597091223
# 23            1        3.60      US  1597091235
# ..          ...         ...     ...         ...
# 557          19        3.10      FR  1597092113
# 558           1        2.60      US  1597092114
# 559          90        3.60      RE  1597092115
# 564          16        1.50      RO  1597092121
# 565           1        1.10      CD  1597092122
#
#                                    Hotel Name Hotel Rating  \
# 1    DoubleTree by Hilton Hotel Alice Springs          4.1
# 9                Casa Laguna, Bed & Breakfast          4.7
# 10          Sofitel Legend Old Cataract Aswan          4.9
# 13
# 23                                Craig Hotel          4.5
# ..                                        ...          ...
# 557                     Château du Mont Suzey          4.7
# 558        Hampton Inn & Suites Mountain Home          4.4
# 559                       Iloha Seaview Hotel          4.3
# 564                       Hotel Saint Germain          4.6
# 565                 hôtel paradis de Tshikapa          2.5
#
#                                          Hotel Address
# 1                         82 Barrett Dr, Alice Springs
# 9    Baja California, El Domino, Centro, Guerrero N...
# 10                             Abtal El Tahrir, Street
# 13
# 23                                 377 Cedar Ct, Craig
# ..                                                 ...
# 557                Château Mont-Suzey,, Yvoy-le-Marron
# 558              3175 NE, Foothills Ave, Mountain Home
# 559  Pointe des Châteaux, 44 Rue Georges Pompidou, ...
# 564                  Strada Grădinii Publice 1, Brăila
# 565  av taba Congo ville de Tshikapa, ville de Tshi...
#
# [125 rows x 12 columns]

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row


# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Latitude", "Longitude"]]

# %%
# Add marker layer ontop of heat map

gmaps.configure(api_key=g_key)
locations = hotel_df[["Latitude", "Longitude"]]
humid = hotel_df["Humidity"]

# Display figure
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humid, 
                                 dissipating=False, max_intensity=10,
                                 point_radius = 1)

hotel_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2,
    info_box_content= hotel_info
)


fig.add_layer(heat_layer)
fig.add_layer(hotel_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
